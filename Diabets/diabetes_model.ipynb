# %%
#Installation des packages
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\fred\\ML\\Technohacks\\Diabets\\diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
X=df.drop(["Outcome"],axis=1)
y=df["Outcome"]

# %%
#Normalisation
X=StandardScaler().fit_transform(X)
print(X)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)
print(X_train.shape,X_test.shape)
# Out:
# (614, 8) (154, 8)

# %%
import tensorflow as tf

# %%
model=tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Dense(units=15,activation="relu",kernel_initializer="uniform",input_dim=8))
model.add(tf.keras.layers.Dense(units=1,activation="sigmoid",kernel_initializer="uniform"))

# %%
model.compile(optimizer='adam',loss="binary_crossentropy",metrics=['binary_accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 15)                135
#
#  dense_3 (Dense)             (None, 1)                 16
#
# ...
# Total params: 151 (604.00 Byte)
# Trainable params: 151 (604.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train,y_train,batch_size=10,epochs=500)
# Out:
# Epoch 1/500
# 62/62 [==============================] - 3s 5ms/step - loss: 0.6837 - binary_accuracy: 0.6694
# Epoch 2/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6450 - binary_accuracy: 0.6987
# Epoch 3/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5850 - binary_accuracy: 0.7508
# Epoch 4/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5355 - binary_accuracy: 0.7573
# Epoch 5/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5071 - binary_accuracy: 0.7573
# Epoch 6/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4926 - binary_accuracy: 0.7590
# Epoch 7/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4851 - binary_accuracy: 0.7606
# Epoch 8/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4792 - binary_accuracy: 0.7720
# Epoch 9/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4758 - binary_accuracy: 0.7687
# ...

# %%
test_loss,acc_loss=model.evaluate(X_test,y_test)
# Out:
# 5/5 [==============================] - 1s 8ms/step - loss: 0.5076 - binary_accuracy: 0.7792
